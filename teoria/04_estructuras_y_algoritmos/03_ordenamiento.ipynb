# %% [markdown]
# ---
# title: "3 - Algoritmos de ordenamiento"
# toc: true
# filters:
#   - carousel
# ---

# %% [markdown]
# ## Introducción
#
# - ¿Por qué ordenamos?
# - ¿Cómo funcionan los algoritmos de ordenamiento en Python?
# - ¿Qué estructuras tiene sentido ordenar?
#     - ¡Aquellas que tienen orden!
# - Enlazarlo a los resultados del TP grupal, donde algunos algoritmos tardaban más que otros...
#     - El resultado es el mismo, pero el tiempo es distinto, ¿por qué?
#     - ¿La cantidad de pasos es distinta? ¿Un algoritmo realiza pasos más baratos que otros?

# %% [markdown]
# ## _Bubble sort_

# %% [markdown]
# Descripción
#
# - Presentar un arreglo, pequeño, de números.
# - Desarrollar el paso a paso para ordenarlo, de manera intuitiva (pero siguiendo al bubble sort)
# - Una vez ordenado, resumir los pasos.
# - Luego, mostrar implementación en Python.
#
# Eficiencia
#
# - ¿Peor caso? ¿Mejor caso?

# %% [markdown]
# ::: {style="width: 70%; margin: auto;"}
# ::: {.carousel id="carousel-01"}
#
# ![](.//imgs/03/bubble_sort-0.png)
#
# ![](.//imgs/03/bubble_sort-1.png)
#
# ![](.//imgs/03/bubble_sort-2.png)
#
# ![](.//imgs/03/bubble_sort-3.png)
#
# ![](.//imgs/03/bubble_sort-4.png)
#
# ![](.//imgs/03/bubble_sort-5.png)
#
# ![](.//imgs/03/bubble_sort-6.png)
#
# ![](.//imgs/03/bubble_sort-7.png)
#
# :::
# :::

# %% [markdown]
# Hola..

# %% [markdown]
# ::: {style="width: 70%; margin: auto;"}
# ::: {.carousel id="carousel-02"}
#
# ![](.//imgs/03/bubble_sort_2-0.png)
#
# ![](.//imgs/03/bubble_sort_2-1.png)
#
# ![](.//imgs/03/bubble_sort_2-2.png)
#
# ![](.//imgs/03/bubble_sort_2-3.png)
#
# ![](.//imgs/03/bubble_sort_2-4.png)
#
# ![](.//imgs/03/bubble_sort_2-5.png)
#
# ![](.//imgs/03/bubble_sort_2-6.png)
#
# ![](.//imgs/03/bubble_sort_2-7.png)
#
# ![](.//imgs/03/bubble_sort_2-8.png)
#
# ![](.//imgs/03/bubble_sort_2-9.png)
#
# ![](.//imgs/03/bubble_sort_2-10.png)
#
# ![](.//imgs/03/bubble_sort_2-11.png)
#
# ![](.//imgs/03/bubble_sort_2-12.png)
#
# ![](.//imgs/03/bubble_sort_2-13.png)
#
# ![](.//imgs/03/bubble_sort_2-14.png)
#
# :::
# :::

# %% [markdown]
# ## _Selection sort_
#
# Descripción
#
# - No hay una única forma de ir "creciendo" una lista ordenada. Una de las contras del algoritmo anterior es que cada vez que tomamos un valor, no sabemos donde lo vamos a colocar.
# - Una alternativa este algoritmo, donde se va "populando" una lista ordenada de menor a mayor, a partir de encontrar el valor mínimo de una sublista.
#     - Puede hacerse en la misma lista (también podría hacerse una copia).
#     - ¿Tiene sentido con listas enlazadas?
# - Resumir pasos.
# - Mostrar implementación en Python.
#
# Eficiencia
#
# * ¿Peor caso? ¿Mejor caso?
#
# Comparaciones y reflexiones

# %% [markdown]
# ::: {style="width: 70%; margin: auto;"}
# ::: {.carousel id="carousel-03"}
#
# ![](.//imgs/03/selection_sort-0.png)
#
# ![](.//imgs/03/selection_sort-1.png)
#
# ![](.//imgs/03/selection_sort-2.png)
#
# ![](.//imgs/03/selection_sort-3.png)
#
# ![](.//imgs/03/selection_sort-4.png)
#
# ![](.//imgs/03/selection_sort-5.png)
#
# ![](.//imgs/03/selection_sort-6.png)
#
# ![](.//imgs/03/selection_sort-7.png)
#
# ![](.//imgs/03/selection_sort-8.png)
#
# ![](.//imgs/03/selection_sort-9.png)
#
# ![](.//imgs/03/selection_sort-10.png)
#
# ![](.//imgs/03/selection_sort-11.png)
#
# ![](.//imgs/03/selection_sort-12.png)
#
# ![](.//imgs/03/selection_sort-13.png)
#
# ![](.//imgs/03/selection_sort-14.png)
#
# ![](.//imgs/03/selection_sort-15.png)
#
# ![](.//imgs/03/selection_sort-16.png)
#
# :::
# :::

# %% [markdown]
# En el mejor de los casos, el arreglo está inicialmente en orden, el algoritmo solo hace una pasada y entonces la complejidad es O(n).
#  En el peor caso, con el arreglo ordenado con el criterio contrario, se obtiene una complejidad temporal cuadrática del orden de O(n^2/2).
#
#  - ¡Optimiza para el mejor escenario!

# %% [markdown]
# ## _Insertion sort_
#
# Descripción
#
# - Presentar el mismo arreglo que en la sección anterior.
# - En vez de ir ordenando de a pares, por qué no mantener un arreglo ordenado, que va creciendo, donde vamos insertando elementos
# en orden.
# - Mostrar el paso a paso, y el resultado.
# - Una vez ordenado, resumir los pasos.
# - Luego, mostrar la implementación en Python.
#
# Eficiencia
#
# - ¿Peor caso? ¿Mejor caso?

# %% [markdown]
# ::: {style="width: 70%; margin: auto;"}
# ::: {.carousel id="carousel-04"}
#
# ![](.//imgs/03/insertion_sort-0.png)
#
# ![](.//imgs/03/insertion_sort-1.png)
#
# ![](.//imgs/03/insertion_sort-2.png)
#
# ![](.//imgs/03/insertion_sort-3.png)
#
# ![](.//imgs/03/insertion_sort-4.png)
#
# ![](.//imgs/03/insertion_sort-5.png)
#
# ![](.//imgs/03/insertion_sort-6.png)
#
# ![](.//imgs/03/insertion_sort-7.png)
#
# ![](.//imgs/03/insertion_sort-8.png)
#
# ![](.//imgs/03/insertion_sort-9.png)
#
# ![](.//imgs/03/insertion_sort-10.png)
#
# ![](.//imgs/03/insertion_sort-11.png)
#
# ![](.//imgs/03/insertion_sort-12.png)
#
# ![](.//imgs/03/insertion_sort-13.png)
#
# ![](.//imgs/03/insertion_sort-14.png)
#
# ![](.//imgs/03/insertion_sort-15.png)
#
# :::
# :::

# %% [markdown]
# ## Divide y vencerás
#
# - Complejidad de los algoritmos anteriores
#     - La cantidad de pasos crece cuadráticamente.
#     - Que el arreglo crezca en 1 puede incrementar sustancialmente la cantidad de pasos a realizar.
# - Ordenar listas más pequeñas es sustancialmente más rápido que ordenar listas más grandes
# - Ordenar una lista parcialmente ordenada es más rápido que una lista totalmente desordenada
# - ¿Por qué no dividir el arreglo en partes más pequeñas y ordenar esas?
#     - Esta estrategia es la que siguen los siguientes dos algoritmos que vamos a analizar, que alcanzan un mejor desempeño que los vistos anteriormente.

# %% [markdown]
# ## _Quick sort_
#
# Descripción
#
# * Explicacion, con diagramas y todo. Paso a paso de un ordenamiento.
# * Resumen de pasos (no sé si es tan fácil en texto)
# * Mostrar implementación en Python.
#
# Eficiencia
#
# * ¿Diagrama?
# * Mejor y peor caso

# %% [markdown]
# ## _Merge sort_
#
# Explicación similar a quick sort...

# %% [markdown]
# ## Resumen
#
# Tabla comparativa y luego algunas reflexiones.
